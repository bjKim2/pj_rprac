# %%
df<- read.csv("./movies/temp_actors_juyeoun.csv")

# %%
df<- df[,-1]

# %%
df[df$영화명 == "공조",]
# Out:
#    영화명 누적매출액  누적관객수 스크린수 상영횟수 개봉일     배급사
# 16 공조   63783303326 7817654    1392     142991   2017-01-18 (주)씨제이이엔엠
#    등급           장르 감독   배우
# 16 15세이상관람가 액션 김성훈 현빈,유해진,김주혁
#    제작사
# 16 (주)제이케이필름,(주)씨제이이엔엠,영화사 이창,(주)에이치비엔터테인먼트
#    cluster
# 16 3

# %%
nrow(df)
# Out:
# [1] 109

# %%
df$배우 <- as.character(df$배우)

# %%
df[df$배우 == "",]
# Out:
#      영화명 누적매출액 누적관객수 스크린수 상영횟수 개봉일 배급사 등급 장르
#      감독 배우 제작사 cluster

# %%
df[df$영화명 == "하모니", "배우"] <- "김윤진,나문희,강예원,이다희,장영남,박준면,정수영"

# %%
df[df$영화명 == "웰컴 투 동막골", "배우"] <- "장재영,신하균,강혜정"

# %%
df[df$영화명 == "숨바꼭질", "배우"] <- "손현주,문정희,전미선"

# %%
df[df$cluster == 2,]
# Out:
#     영화명                      누적매출액  누적관객수 스크린수 상영횟수
# 2   7급 공무원                  26380710000 4039891     475      90779
# 3   82년생 김지영               30298542310 3678156    1486     145441
# 5   감기                        21774884000 3117859     806      55046
# 8   강철중: 공공의 적 1-1       28638460100 4313101     707      74157
# 9   거북이 달린다               20618276000 3024666     432      69946
# 10  건축학개론                  30223590400 4111237     593     106069
# 14  공공의 적 2                 20091127000 3134421     299      40642
# 20  국가부도의 날               30893315837 3755233    1180     101077
# 23  귀향                        27249801990 3587182     876      90288
# 24  그것만이 내 세상            27456797382 3420172     956      95437
# 26  꾼                          31313568795 4018341    1314     117419
# 27  끝까지 간다                 27007303900 3450305     645      84876
# 29  남한산성                    31225419792 3849129    1229      71102
# ...

# %%
for(i in 1:nrow(df)){
    if(df$cluster[i] == 1){
        df$cluster[i] = 2
    }else if(df$cluster[i] == 2){
        df$cluster[i] = 1
    }
}

# %%
head(df)
# Out:
#   영화명                    누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 1 1987                      58169776145 7232387    1299     138226   2017-12-27
# 2 7급 공무원                26380710000 4039891     475      90779   2009-04-22
# 3 82년생 김지영             30298542310 3678156    1486     145441   2019-10-23
# 4 가문의 위기(가문의 영광2) 28622355500 4529876     351      61009   2005-09-07
# 5 감기                      21774884000 3117859     806      55046   2013-08-14
# 6 감시자들                  39380162179 5508017     949     100309   2013-07-03
#   배급사                           등급           장르
# 1 (주)씨제이이엔엠                 15세이상관람가 드라마
# 2 롯데쇼핑㈜롯데엔터테인먼트       12세이상관람가 코미디,액션,드라마,범죄
# 3 롯데컬처웍스(주)롯데엔터테인먼트 12세이상관람가 드라마
# 4 (주)쇼박스                       15세관람가     코미디
# 5 아이러브시네마                   15세이상관람가 드라마,어드벤처,액션
# 6 (주)넥스트엔터테인먼트월드(NEW)  15세이상관람가 범죄,액션
#   감독          배우
# 1 장준환        김윤석,하정우,유해진,김태리,박희순,이희준
# 2 신태라        김하늘,강지환
# 3 김도영        정유미,공유
# 4 정용기        신현준,김원희,김수미
# 5 김성수        장혁,수애,박민하
# ...

# %%
write.csv(df,"./movies/juyeounssi.csv",row.names=F)
