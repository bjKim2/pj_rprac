# %%
library(httr)
?httr

# %%
url = "https://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=f5eef3421c602c6cb7ea224104795888&movieCd=20124077"
simple_resp <- GET(url)

# %%
simple_resp
# Out:
# Response [https://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=f5eef3421c602c6cb7ea224104795888&movieCd=20124077]
#   Date: 2022-06-03 08:47
#   Status: 200
#   Content-Type: application/json;charset=utf-8
#   Size: 692 B

# %%
library(rvest)

# %%
simple_text <- content(simple_resp, as="text", encoding="utf-8")
simple_text
# Out:
# [1] "{\"movieInfoResult\":{\"movieInfo\":{\"movieCd\":\"20124077\",\"movieNm\":\"슬픈 전설\",\"movieNmEn\":\"\",\"movieNmOg\":\"\",\"showTm\":\"\",\"prdtYear\":\"2012\",\"openDt\":\"\",\"prdtStatNm\":\"촬영진행\",\"typeNm\":\"장편\",\"nations\":[{\"nationNm\":\"한국\"}],\"genres\":[{\"genreNm\":\"다큐멘터리\"}],\"directors\":[{\"peopleNm\":\"김명준\",\"peopleNmEn\":\"KIM Myeong-joon\"}],\"actors\":[],\"showTypes\":[{\"showTypeGroupNm\":\"필름\",\"showTypeNm\":\"필름\"}],\"companys\":[{\"companyCd\":\"20100036\",\"companyNm\":\"㈜인디스토리\",\"companyNmEn\":\"INDIESTORY Inc. \",\"companyPartNm\":\"제작사\"}],\"audits\":[],\"staffs\":[{\"peopleNm\":\"조은성\",\"peopleNmEn\":\"CHO Eun-sung\",\"staffRoleNm\":\"프로듀서\"}]},\"source\":\"영화진흥위원회\"}}"

# %%
simple_list <- content(simple_resp, as="parse", encoding="utf-8")
simple_list$movieInfoResult
# Out:
# $movieInfo
# $movieInfo$movieCd
# [1] "20124077"
#
# $movieInfo$movieNm
# [1] "슬픈 전설"
#
# $movieInfo$movieNmEn
# [1] ""
#
# $movieInfo$movieNmOg
# [1] ""
#
# $movieInfo$showTm
# [1] ""
#
# $movieInfo$prdtYear
# [1] "2012"
#
# $movieInfo$openDt
# [1] ""
#
# $movieInfo$prdtStatNm
# [1] "촬영진행"
#
# $movieInfo$typeNm
# [1] "장편"
#
# $movieInfo$nations
# $movieInfo$nations[[1]]
# $movieInfo$nations[[1]]$nationNm
# [1] "한국"
#
#
#
# $movieInfo$genres
# $movieInfo$genres[[1]]
# $movieInfo$genres[[1]]$genreNm
# [1] "다큐멘터리"
#
#
#
# $movieInfo$directors
# $movieInfo$directors[[1]]
# $movieInfo$directors[[1]]$peopleNm
# [1] "김명준"
#
# $movieInfo$directors[[1]]$peopleNmEn
# [1] "KIM Myeong-joon"
#
#
#
# $movieInfo$actors
# list()
#
# $movieInfo$showTypes
# $movieInfo$showTypes[[1]]
# $movieInfo$showTypes[[1]]$showTypeGroupNm
# [1] "필름"
#
# $movieInfo$showTypes[[1]]$showTypeNm
# [1] "필름"
#
#
#
# $movieInfo$companys
# $movieInfo$companys[[1]]
# $movieInfo$companys[[1]]$companyCd
# [1] "20100036"
#
# $movieInfo$companys[[1]]$companyNm
# [1] "㈜인디스토리"
#
# $movieInfo$companys[[1]]$companyNmEn
# [1] "INDIESTORY Inc. "
#
# $movieInfo$companys[[1]]$companyPartNm
# [1] "제작사"
#
#
#
# $movieInfo$audits
# list()
#
# $movieInfo$staffs
# $movieInfo$staffs[[1]]
# $movieInfo$staffs[[1]]$peopleNm
# [1] "조은성"
#
# $movieInfo$staffs[[1]]$peopleNmEn
# [1] "CHO Eun-sung"
#
# $movieInfo$staffs[[1]]$staffRoleNm
# [1] "프로듀서"
#
#
#
#
# $source
# [1] "영화진흥위원회"

# %%
simple_list$movieInfoResult$movieInfo$nations
# Out:
# [[1]]
# [[1]]$nationNm
# [1] "한국"
