# %%
juy <- read.csv("./movies/juyeounssi.csv", stringsAsFactors = F)
ver4 <- read.csv("./movies/new_movie_ver4.csv" ,stringsAsFactors = F)
ver5 <- read.csv("./movies/new_movie_ver5.csv")
ver6 <- read.csv("./movies/new_movie_ver6.csv")
ver7 <- read.csv("./movies/new_movie_ver7.csv")
ver8 <- read.csv("./movies/new_movie_ver8.csv")

# %%
str(juy)
# Out:
# 'data.frame':	109 obs. of  13 variables:
#  $ 영화명    : chr  "1987" "7급 공무원" "82년생 김지영" "가문의 위기(가문의 영광2)" ...
#  $ 누적매출액: num  5.82e+10 2.64e+10 3.03e+10 2.86e+10 2.18e+10 ...
#  $ 누적관객수: int  7232387 4039891 3678156 4529876 3117859 5508017 4452850 4313101 3024666 4111237 ...
#  $ 스크린수  : int  1299 475 1486 351 806 949 1426 707 432 593 ...
#  $ 상영횟수  : int  138226 90779 145441 61009 55046 100309 80359 74157 69946 106069 ...
#  $ 개봉일    : chr  "2017-12-27" "2009-04-22" "2019-10-23" "2005-09-07" ...
#  $ 배급사    : chr  "(주)씨제이이엔엠" "롯데쇼핑㈜롯데엔터테인먼트" "롯데컬처웍스(주)롯데엔터테인먼트" "(주)쇼박스" ...
#  $ 등급      : chr  "15세이상관람가" "12세이상관람가" "12세이상관람가" "15세관람가" ...
#  $ 장르      : chr  "드라마" "코미디,액션,드라마,범죄" "드라마" "코미디" ...
#  $ 감독      : chr  "장준환" "신태라" "김도영" "정용기" ...
#  $ 배우      : chr  "김윤석,하정우,유해진,김태리,박희순,이희준" "김하늘,강지환" "정유미,공유" "신현준,김원희,김수미" ...
#  $ 제작사    : chr  "(주)우정필름" "(주)하리마오픽쳐스,(주)영화사수작,(주)디씨지플러스" "(주)봄바람영화사" "(주)태원엔터테인먼트" ...
#  $ cluster   : int  3 1 1 2 1 2 2 1 1 1 ...

# %%
library(dplyr)

# %%
juy<- arrange(juy,누적관객수)
ver4<- arrange(ver4,누적관객수)

# %%
nrow(juy)
nrow(ver4)
# Out:
# [1] 109
# [1] 109

# %%
#new_movie_ver4.csv : 단역 제외한 배우로 바꿈
#new_movie_ver5.csv : 감독_배우 컬럼 추가 후 로우 수 증가
#ver6 업데이트 내용 : 클러스터 1 과 2를 숫자 바꾸고, 배우 2명으로 줄임
#ver 7 업데이트 내용: 배우 2 명을 한샘플에 넣지 않고 샘플 수를 2배로 늘려 한샘플에 한배우입력
#ver 8 업데이트 : cj enm 한글명 을 영문명으로 바꿈

# %%
str(ver4)
# Out:
# 'data.frame':	109 obs. of  13 variables:
#  $ 영화명    : chr  "오싹한 연애" "하모니" "헬로우 고스트" "거북이 달린다" ...
#  $ 누적매출액: num  2.20e+10 2.16e+10 2.21e+10 2.06e+10 2.36e+10 ...
#  $ 누적관객수: int  3009356 3018154 3019780 3024666 3044859 3117859 3119682 3125069 3134421 3152895 ...
#  $ 스크린수  : int  544 384 472 432 926 806 386 514 299 1137 ...
#  $ 상영횟수  : int  62913 77732 57578 69946 100167 55046 41438 60714 40642 107909 ...
#  $ 개봉일    : chr  "2011-12-01" "2010-01-28" "2010-12-22" "2009-06-11" ...
#  $ 배급사    : chr  "(주)씨제이이엔엠" "CJ ENM" "(주)넥스트엔터테인먼트월드(NEW)" "(주)쇼박스" ...
#  $ 등급      : chr  "12세이상관람가" "12세이상관람가" "12세이상관람가" "15세이상관람가" ...
#  $ 장르      : chr  "공포(호러),멜로/로맨스,코미디" "드라마" "코미디,드라마" "드라마,액션,범죄" ...
#  $ 감독      : chr  "황인호" "강대규" "김영탁" "이연우" ...
#  $ 배우      : chr  "손예진,이민기,박철민,김현숙,이미도,신성훈,윤지민,황승언,이현진" "김윤진,나문희,강예원,이다희,장영남,박준면,정수영,임채연,이선주,김호연,정혜원,신정원,지성원,박혜진" "차태현,강예원,이문수,고창석,장영남,천보근,공호석,정규수,김진성,구승현" "김윤석,정경호,견미리,선우선,김지나,신정근,최권,차은재,주진모,이무생,유하복,임형택,김희원" ...
# ...

# %%
head(juy)
# Out:
#   영화명        누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 1 오싹한 연애   22010977000 3009356    544       62913   2011-12-01
# 2 하모니        21641865000 3018154    384       77732   2010-01-28
# 3 헬로우 고스트 22056966500 3019780    472       57578   2010-12-22
# 4 거북이 달린다 20618276000 3024666    432       69946   2009-06-11
# 5 스물          23563705686 3044859    926      100167   2015-03-25
# 6 감기          21774884000 3117859    806       55046   2013-08-14
#   배급사                          등급           장르
# 1 (주)씨제이이엔엠                12세이상관람가 공포(호러),멜로/로맨스,코미디
# 2 CJ ENM                          12세이상관람가 드라마
# 3 (주)넥스트엔터테인먼트월드(NEW) 12세이상관람가 코미디,드라마
# 4 (주)쇼박스                      15세이상관람가 드라마,액션,범죄
# 5 (주)넥스트엔터테인먼트월드(NEW) 15세이상관람가 코미디,드라마
# 6 아이러브시네마                  15세이상관람가 드라마,어드벤처,액션
#   감독   배우
# 1 황인호 손예진,이민기
# 2 강대규 김윤진,나문희,강예원,이다희,장영남,박준면,정수영
# 3 김영탁 차태현,강예원,이문수,고창석,장영남,천보근
# 4 이연우 김윤석,정경호,견미리,선우선
# 5 이병헌 김우빈,준호,강하늘
# 6 김성수 장혁,수애,박민하
#   제작사                                             cluster
# ...

# %%
joy <-ver4

# %%
for(i in 1:nrow(ver4)){
    joy$배우[i] <- substr(joy$배우[i], nchar(juy$배우[i])+2, nchar(joy$배우[i]) )

}

# %%
head(juy)
# Out:
#   영화명        누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 1 오싹한 연애   22010977000 3009356    544       62913   2011-12-01
# 2 하모니        21641865000 3018154    384       77732   2010-01-28
# 3 헬로우 고스트 22056966500 3019780    472       57578   2010-12-22
# 4 거북이 달린다 20618276000 3024666    432       69946   2009-06-11
# 5 스물          23563705686 3044859    926      100167   2015-03-25
# 6 감기          21774884000 3117859    806       55046   2013-08-14
#   배급사                          등급           장르
# 1 (주)씨제이이엔엠                12세이상관람가 공포(호러),멜로/로맨스,코미디
# 2 CJ ENM                          12세이상관람가 드라마
# 3 (주)넥스트엔터테인먼트월드(NEW) 12세이상관람가 코미디,드라마
# 4 (주)쇼박스                      15세이상관람가 드라마,액션,범죄
# 5 (주)넥스트엔터테인먼트월드(NEW) 15세이상관람가 코미디,드라마
# 6 아이러브시네마                  15세이상관람가 드라마,어드벤처,액션
#   감독   배우
# 1 황인호 손예진,이민기
# 2 강대규 김윤진,나문희,강예원,이다희,장영남,박준면,정수영
# 3 김영탁 차태현,강예원,이문수,고창석,장영남,천보근
# 4 이연우 김윤석,정경호,견미리,선우선
# 5 이병헌 김우빈,준호,강하늘
# 6 김성수 장혁,수애,박민하
#   제작사                                             cluster
# ...

# %%
head(joy)
# Out:
#   영화명        누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 1 오싹한 연애   22010977000 3009356    544       62913   2011-12-01
# 2 하모니        21641865000 3018154    384       77732   2010-01-28
# 3 헬로우 고스트 22056966500 3019780    472       57578   2010-12-22
# 4 거북이 달린다 20618276000 3024666    432       69946   2009-06-11
# 5 스물          23563705686 3044859    926      100167   2015-03-25
# 6 감기          21774884000 3117859    806       55046   2013-08-14
#   배급사                          등급           장르
# 1 (주)씨제이이엔엠                12세이상관람가 공포(호러),멜로/로맨스,코미디
# 2 CJ ENM                          12세이상관람가 드라마
# 3 (주)넥스트엔터테인먼트월드(NEW) 12세이상관람가 코미디,드라마
# 4 (주)쇼박스                      15세이상관람가 드라마,액션,범죄
# 5 (주)넥스트엔터테인먼트월드(NEW) 15세이상관람가 코미디,드라마
# 6 아이러브시네마                  15세이상관람가 드라마,어드벤처,액션
#   감독
# 1 황인호
# 2 강대규
# 3 김영탁
# 4 이연우
# 5 이병헌
# 6 김성수
#   배우
# 1 박철민,김현숙,이미도,신성훈,윤지민,황승언,이현진
# 2 임채연,이선주,김호연,정혜원,신정원,지성원,박혜진
# 3 공호석,정규수,김진성,구승현
# 4 김지나,신정근,최권,차은재,주진모,이무생,유하복,임형택,김희원
# 5 정소민,이유비,민효린,정주연
# ...

# %%
df<- juy

# %%
df$조연 <- joy$배우

# %%
head(df)
# Out:
#   영화명        누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 1 오싹한 연애   22010977000 3009356    544       62913   2011-12-01
# 2 하모니        21641865000 3018154    384       77732   2010-01-28
# 3 헬로우 고스트 22056966500 3019780    472       57578   2010-12-22
# 4 거북이 달린다 20618276000 3024666    432       69946   2009-06-11
# 5 스물          23563705686 3044859    926      100167   2015-03-25
# 6 감기          21774884000 3117859    806       55046   2013-08-14
#   배급사                          등급           장르
# 1 (주)씨제이이엔엠                12세이상관람가 공포(호러),멜로/로맨스,코미디
# 2 CJ ENM                          12세이상관람가 드라마
# 3 (주)넥스트엔터테인먼트월드(NEW) 12세이상관람가 코미디,드라마
# 4 (주)쇼박스                      15세이상관람가 드라마,액션,범죄
# 5 (주)넥스트엔터테인먼트월드(NEW) 15세이상관람가 코미디,드라마
# 6 아이러브시네마                  15세이상관람가 드라마,어드벤처,액션
#   감독   배우
# 1 황인호 손예진,이민기
# 2 강대규 김윤진,나문희,강예원,이다희,장영남,박준면,정수영
# 3 김영탁 차태현,강예원,이문수,고창석,장영남,천보근
# 4 이연우 김윤석,정경호,견미리,선우선
# 5 이병헌 김우빈,준호,강하늘
# 6 김성수 장혁,수애,박민하
#   제작사                                             cluster
# ...

# %%
juy[juy$영화명 =="강철비", ]
# Out:
#    영화명 누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 44 강철비 35490346466 4452850    1426     80359    2017-12-14
#    배급사                          등급           장르        감독
# 44 (주)넥스트엔터테인먼트월드(NEW) 15세이상관람가 액션,드라마 양우석
#    배우          제작사                            cluster
# 44 정우성,곽도원 (주)와이웍스엔터테인먼트,(주)모팩 2

# %%
joy[joy$영화명 =="강철비", "배우"] <- "김갑수,김의성,이경영,조우진,정원중,장현성,김명곤,박은혜,박선영,안미나,원진아,이재용,이윤건,김형종"

# %%
df[df$영화명 == "강철비","조연"] <-"김갑수,김의성,이경영,조우진,정원중,장현성,김명곤,박은혜,박선영,안미나,원진아,이재용,이윤건,김형종"

# %%
table(df$배급사 == "")
# Out:
#             (주)넥스트엔터테인먼트월드(NEW)
#                                          14
#                                  (주)쇼박스
#                                          29
#                            (주)시네마서비스
#                                           1
#                                (주)싸이더스
#                                           1
#                            (주)씨제이이엔엠
#                                          29
#         (주)씨제이이엔엠,(주)덱스터스튜디오
#                                           1
# (주)에이스메이커무비웍스,(주)키위미디어그룹
#                                           1
#                              (주)와우픽쳐스
#                                           1
#                  롯데쇼핑㈜롯데엔터테인먼트
#                                          10
# 롯데쇼핑㈜롯데엔터테인먼트,(주)리틀빅픽쳐스
#                                           1
#     롯데쇼핑㈜롯데엔터테인먼트,(주)싸이더스
#                                           1
#            롯데컬처웍스(주)롯데엔터테인먼트
#                                           2
# 메가박스중앙(주)플러스엠,(주)키위미디어그룹
# ...

# %%
for(i in 1:nrow(df)){
    if(df[i,"배급사"] == "(주)씨제이이엔엠" ){
        df[i,"배급사"] <- "CJ ENM"
    }
}

# %%
for(i in 1:nrow(df)){
    if(df[i,"배급사"] == "(주)씨제이이엔엠,(주)덱스터스튜디오" ){
        df[i,"배급사"] <- "CJ ENM,(주)덱스터스튜디오"
    }
}

# %%
write.csv(df,"./movies/movie109_ver1.csv",row.names = F)
