# %%
df<-read.csv("../movies/ju_score.csv")

# %%
head(df)
# Out:
#   주연   총횟수 cluster 횟수 누적관객수__개봉일스크린수 누적관객수__스크린수
# 1 강동원 17     1       1    13949.4194                 10547.1220
# 2 강동원 17     2       4    24378.6490                 20016.5375
# 3 강동원 17     3       7    36059.3428                 32646.7485
# 4 강동원 17     4       5    22810.6794                 19943.2326
# 5 강소라  4     1       1      422.5125                   397.6588
# 6 강소라  4     2       2    19058.6058                 13760.9423
#   누적관객수__상영횟수 평균_관람객_개스크 평균_관람객_스크 평균_관람객_상횟
# 1 101.53369            13949.4194         10547.1220       101.53369
# 2 195.79140             6094.6623          5004.1344        48.94785
# 3 272.82261             5151.3347          4663.8212        38.97466
# 4 278.25154             4562.1359          3988.6465        55.65031
# 5  13.78507              422.5125           397.6588        13.78507
# 6  64.68185             9529.3029          6880.4712        32.34093
#   관람객개스크점수
# 1 13949.4194
# 2 12189.3245
# 3 13629.1505
# 4 10201.2459
# ...

# %%
df$최종점수 <- df$평균_관람객_개스크 * (df$cluster * df$횟수)

# %%
hist(subset(df, df$cluster == 4)$최종점수)
# Out:
# Warning message in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...):
# “conversion failure on 'Histogram of subset(df, df$cluster == 4)$최종점수' in 'mbcsToSbcs': dot substituted for <ec>”Warning message in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...):
# “conversion failure on 'Histogram of subset(df, df$cluster == 4)$최종점수' in 'mbcsToSbcs': dot substituted for <b5>”Warning message in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...):
# “conversion failure on 'Histogram of subset(df, df$cluster == 4)$최종점수' in 'mbcsToSbcs': dot substituted for <9c>”Warning message in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...):
# “conversion failure on 'Histogram of subset(df, df$cluster == 4)$최종점수' in 'mbcsToSbcs': dot substituted for <ec>”Warning message in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...):
# ...

# %%
cor(df$평균_관람객_개스크,df$횟수)
plot(b,a)
# Out:
# [1] 0.1861858
# plot without title

# %%
df$관람객
