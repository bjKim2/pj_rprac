# %%
dir_actor_df <- read.csv("../movies/감독_배우_점수.csv")
df <- read.csv("../movies/over200mil_change_actor.csv")

# %%
library(dplyr)

# %%
head(df)
# Out:
#   영화명       누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 1 1987         58169776145  7232387   1299     138226   2017-12-27
# 2 1번가의 기적 15494122100  2535450    340      54566   2007-02-14
# 3 26년         21242367145  2963652    611      50679   2012-11-29
# 4 7광구        19391653500  2242510    812      47346   2011-08-04
# 5 7급 공무원   26380710000  4039891    475      90779   2009-04-22
# 6 7번방의 선물 91431950670 12811213    866     166817   2013-01-23
#   배급사                          등급           장르                    감독
# 1 (주)씨제이이엔엠                15세이상관람가 드라마                  장준환
# 2 CJ ENM                          15세이상관람가 드라마,코미디           윤제균
# 3 (주)인벤트스톤,영화사청어람(주) 15세이상관람가 액션,드라마             조근현
# 4 (주)씨제이이엔엠                15세이상관람가 SF,액션,스릴러          김지훈
# 5 롯데쇼핑㈜롯데엔터테인먼트      12세이상관람가 코미디,액션,드라마,범죄 신태라
# 6 (주)넥스트엔터테인먼트월드(NEW) 15세이상관람가 코미디,드라마           이환경
#   주연
# 1 김윤석,하정우,유해진,김태리,박희순,이희준
# 2 임창정,하지원
# 3 진구,한혜진,임슬옹
# 4 하지원,안성기,오지호,박철민,송새벽
# 5 김하늘,강지환
# 6 류승룡,박신혜,갈소원,오달수,박원상,김정태,정만식,김기천
# ...

# %%
df$조연 <- as.character(df$조연)

# %%
for(i in 1:nrow(df)) 
df$조연[i]<- substr(df$조연[i],2,nchar(df$조연[i]))

# %%
head(df)
# Out:
#   영화명       누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 1 1987         58169776145  7232387   1299     138226   2017-12-27
# 2 1번가의 기적 15494122100  2535450    340      54566   2007-02-14
# 3 26년         21242367145  2963652    611      50679   2012-11-29
# 4 7광구        19391653500  2242510    812      47346   2011-08-04
# 5 7급 공무원   26380710000  4039891    475      90779   2009-04-22
# 6 7번방의 선물 91431950670 12811213    866     166817   2013-01-23
#   배급사                          등급           장르                    감독
# 1 (주)씨제이이엔엠                15세이상관람가 드라마                  장준환
# 2 CJ ENM                          15세이상관람가 드라마,코미디           윤제균
# 3 (주)인벤트스톤,영화사청어람(주) 15세이상관람가 액션,드라마             조근현
# 4 (주)씨제이이엔엠                15세이상관람가 SF,액션,스릴러          김지훈
# 5 롯데쇼핑㈜롯데엔터테인먼트      12세이상관람가 코미디,액션,드라마,범죄 신태라
# 6 (주)넥스트엔터테인먼트월드(NEW) 15세이상관람가 코미디,드라마           이환경
#   주연
# 1 김윤석,하정우,유해진,김태리,박희순,이희준
# 2 임창정,하지원
# 3 진구,한혜진,임슬옹
# 4 하지원,안성기,오지호,박철민,송새벽
# 5 김하늘,강지환
# 6 류승룡,박신혜,갈소원,오달수,박원상,김정태,정만식,김기천
# ...

# %%
#주연배우와 감독의 점수 
df$감독_주연 = 0

# %%
head(df)
# Out:
#   영화명       누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 1 1987         58169776145  7232387   1299     138226   2017-12-27
# 2 1번가의 기적 15494122100  2535450    340      54566   2007-02-14
# 3 26년         21242367145  2963652    611      50679   2012-11-29
# 4 7광구        19391653500  2242510    812      47346   2011-08-04
# 5 7급 공무원   26380710000  4039891    475      90779   2009-04-22
# 6 7번방의 선물 91431950670 12811213    866     166817   2013-01-23
#   배급사                          등급           장르                    감독
# 1 (주)씨제이이엔엠                15세이상관람가 드라마                  장준환
# 2 CJ ENM                          15세이상관람가 드라마,코미디           윤제균
# 3 (주)인벤트스톤,영화사청어람(주) 15세이상관람가 액션,드라마             조근현
# 4 (주)씨제이이엔엠                15세이상관람가 SF,액션,스릴러          김지훈
# 5 롯데쇼핑㈜롯데엔터테인먼트      12세이상관람가 코미디,액션,드라마,범죄 신태라
# 6 (주)넥스트엔터테인먼트월드(NEW) 15세이상관람가 코미디,드라마           이환경
#   주연
# 1 김윤석,하정우,유해진,김태리,박희순,이희준
# 2 임창정,하지원
# 3 진구,한혜진,임슬옹
# 4 하지원,안성기,오지호,박철민,송새벽
# 5 김하늘,강지환
# 6 류승룡,박신혜,갈소원,오달수,박원상,김정태,정만식,김기천
# ...

# %%
dir_actor_df
