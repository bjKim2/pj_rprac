# %%
df <- read.csv("./movies/new_movie_ver1.csv")

# %%
str(df)
# Out:
# 'data.frame':	2710 obs. of  12 variables:
#  $ 영화명    : Factor w/ 2710 levels "...ing","0.0MHz",..: 1 2 3 4 5 7 6 8 9 10 ...
#  $ 누적매출액: num  2.17e+08 1.09e+09 3.11e+09 1.90e+09 6.94e+07 ...
#  $ 누적관객수: int  34300 137294 433866 288452 4078 32616 177 7232387 177 1 ...
#  $ 스크린수  : int  1 446 252 340 35 64 20 1299 20 1 ...
#  $ 상영횟수  : int  1 5998 12744 19036 436 1875 20 138226 20 1 ...
#  $ 개봉일    : Factor w/ 1365 levels "2003-01-30","2003-04-25",..: 6 1219 277 249 544 289 732 941 732 801 ...
#  $ 배급사    : Factor w/ 334 levels "(유)쏘아필름",..: 167 79 96 96 277 326 156 101 156 156 ...
#  $ 등급      : Factor w/ 7 levels "12세관람가","12세이상관람가",..: 1 4 4 4 6 2 7 4 7 7 ...
#  $ 장르      : Factor w/ 224 levels "가족,드라마",..: 24 9 136 108 77 19 54 19 54 54 ...
#  $ 감독      : Factor w/ 930 levels "감수성","감수성,강수성",..: 601 499 784 471 744 705 562 712 588 314 ...
# ...

# %%
# 개봉일 2004/01/01 ~ 2019/12/31 으로 정제 시작 
df$개봉일 <- as.Date(df$개봉일)

# %%
nrow(df)
# Out:
# [1] 2710

# %%
nrow(df[df$개봉일 < as.Date('2004-01-01'),])
# Out:
# [1] 10

# %%
df<- df[df$개봉일 >= as.Date('2004-01-01'),]

# %%
nrow(df)
# Out:
# [1] 2700

# %%
nrow(df[df$개봉일 > as.Date('2019-12-31'),])
# Out:
# [1] 3

# %%
df<- df[df$개봉일 <= as.Date('2019-12-31'),]

# %%
nrow(df)
# Out:
# [1] 2697

# %%
rownames(df) <- c()

# %%
head(df)
# Out:
#   영화명                  누적매출액 누적관객수 스크린수 상영횟수 개봉일
# 1 0.0MHz                  1088258860 137294     446       5998    2019-05-29
# 2 10억                    3107403000 433866     252      12744    2009-08-06
# 3 1724 기방난동사건       1897970000 288452     340      19036    2008-12-03
# 4 1789, 바스티유의 연인들   69354500   4078      35        436    2014-09-18
# 5 19-Nineteen              209955500  32616      64       1875    2009-11-12
# 6 19 섹스 맛있는 속 궁합      930000    177      20         20    2016-09-02
#   배급사                              등급           장르             감독
# 1 (주)스마일이엔티                    15세이상관람가 공포(호러)       유선동
# 2 (주)싸이더스                        15세이상관람가 스릴러,어드벤처  조민호
# 3 (주)싸이더스                        15세이상관람가 사극,액션,코미디 여균동
# 4 유니버설픽쳐스인터내셔널 코리아(유) 전체관람가     뮤지컬,공연      정성복
# 5 CJ ENM                              12세이상관람가 드라마           장용우
# 6 (주)케이알씨지                      청소년관람불가 멜로/로맨스      이민우
#   배우
# ...

# %%
# 개봉일 2004/01/01 ~ 2019/12/31 으로 정제 완료

# %%
# 스크린수 75개 미만 삭제 정제 시작
nrow(df[df$스크린수 < 75,])
# Out:
# [1] 1775

# %%
df<- df[df$스크린수 >= 75,]

# %%
nrow(df)
rownames(df) <- c()
# 스크린수 75개 미만 삭제 정제 완료 2697-> 922개로 줄어듬
# Out:
# [1] 922

# %%
# 배우 NA 값 처리 시작
sum(df$배우 == "")
# Out:
# [1] 2

# %%
df[df$배우  == "",]
# Out:
#     영화명                                 누적매출액 누적관객수 스크린수
# 131 극장판 꼬마버스 타요의 에이스 구출작전 906299900  135478     200
# 455 비스트 앵콜 콘서트 3D                  171432000   16844      75
#     상영횟수 개봉일     배급사                   등급       장르       감독
# 131 5397     2016-01-21 (주)아이코닉스           전체관람가 애니메이션 류정우
# 455  579     2012-02-29 (주)에스비에스콘텐츠허브 전체관람가 공연       손석
#     배우 제작사
# 131      (주)아이코닉스,(주)스튜디오게일
# 455      (주)에스비에스콘텐츠허브

# %%
df$배우 <- as.character(df$배우)

# %%
df[df$영화명 == "극장판 꼬마버스 타요의 에이스 구출작전","배우"] = "신용우,김영선,엄상현,문남숙,정혜옥,전숙경,정미라,김은아"

# %%
df[df$영화명 == "비스트 앵콜 콘서트 3D","배우"] = "윤두준,이기광,양요섭,장현승,용준형,손동운"

# %%
df[df$영화명 == "극장판 꼬마버스 타요의 에이스 구출작전",]
df[df$영화명 == "비스트 앵콜 콘서트 3D",]
# Out:
#     영화명                                 누적매출액 누적관객수 스크린수
# 131 극장판 꼬마버스 타요의 에이스 구출작전 906299900  135478     200
#     상영횟수 개봉일     배급사         등급       장르       감독
# 131 5397     2016-01-21 (주)아이코닉스 전체관람가 애니메이션 류정우
#     배우
# 131 신용우,김영선,엄상현,문남숙,정혜옥,전숙경,정미라,김은아
#     제작사
# 131 (주)아이코닉스,(주)스튜디오게일
#     영화명                누적매출액 누적관객수 스크린수 상영횟수 개봉일
# 455 비스트 앵콜 콘서트 3D 171432000  16844      75       579      2012-02-29
#     배급사                   등급       장르 감독
# 455 (주)에스비에스콘텐츠허브 전체관람가 공연 손석
#     배우                                      제작사
# 455 윤두준,이기광,양요섭,장현승,용준형,손동운 (주)에스비에스콘텐츠허브

# %%
rownames(df) <- c()
# 배우 NA 값 검색 후 대입으로 처리 완료

# %%
write.csv(df,"./movies/new_movie_ver2.csv",row.names=F)
