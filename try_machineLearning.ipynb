# %%
df<-read.csv( "./movies/new_movie_ver8.csv")

# %%
library(dplyr)

# %%
head(df)
# Out:
#   영화명        누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 1 1987          58169776145 7232387    1299     138226   2017-12-27
# 2 1987          58169776145 7232387    1299     138226   2017-12-27
# 3 7급 공무원    26380710000 4039891     475      90779   2009-04-22
# 4 7급 공무원    26380710000 4039891     475      90779   2009-04-22
# 5 82년생 김지영 30298542310 3678156    1486     145441   2019-10-23
# 6 82년생 김지영 30298542310 3678156    1486     145441   2019-10-23
#   배급사                           등급           장르
# 1 CJ ENM                           15세이상관람가 드라마
# 2 CJ ENM                           15세이상관람가 드라마
# 3 롯데쇼핑㈜롯데엔터테인먼트       12세이상관람가 코미디,액션,드라마,범죄
# 4 롯데쇼핑㈜롯데엔터테인먼트       12세이상관람가 코미디,액션,드라마,범죄
# 5 롯데컬처웍스(주)롯데엔터테인먼트 12세이상관람가 드라마
# 6 롯데컬처웍스(주)롯데엔터테인먼트 12세이상관람가 드라마
#   감독   배우   제작사                                             cluster
# 1 장준환 김윤석 (주)우정필름                                       3
# 2 장준환 하정우 (주)우정필름                                       3
# 3 신태라 김하늘 (주)하리마오픽쳐스,(주)영화사수작,(주)디씨지플러스 1
# ...

# %%
x<-c()
for(i in 1:nrow(df)){
    if(df$감독_배우[i] == ""){
        x <- c(x,i)
    }
}
x
# Out:
#  [1]   3   4   5   6   7   8  11  12  13  14  19  20  27  28  33  34  47  48  51
# [20]  52  53  54  55  56  59  60  63  64  71  72  73  74  75  76  77  78  79  80
# [39]  85  86  87  88  93  94  95  96  97  98  99 100 115 116 117 118 121 122 125
# [58] 126 129 130 133 134 137 138 139 140 143 144 149 150 151 152 157 158 161 162
# [77] 163 164 179 180 195 196 197 198 201 202 205 206 207 208 209 210 213 214 215
# [96] 216

# %%
df <- df[-x,]

# %%
head(df,10)
# Out:
#    영화명                누적매출액  누적관객수 스크린수 상영횟수 개봉일
# 1  1987                  58169776145 7232387    1299     138226   2017-12-27
# 2  1987                  58169776145 7232387    1299     138226   2017-12-27
# 9  감기                  21774884000 3117859     806      55046   2013-08-14
# 10 감기                  21774884000 3117859     806      55046   2013-08-14
# 15 강철중: 공공의 적 1-1 28638460100 4313101     707      74157   2008-06-19
# 16 강철중: 공공의 적 1-1 28638460100 4313101     707      74157   2008-06-19
# 17 거북이 달린다         20618276000 3024666     432      69946   2009-06-11
# 18 거북이 달린다         20618276000 3024666     432      69946   2009-06-11
# 21 검사외전              77320403264 9707581    1812     153532   2016-02-03
# 22 검사외전              77320403264 9707581    1812     153532   2016-02-03
#    배급사                  등급           장르                 감독   배우
# 1  CJ ENM                  15세이상관람가 드라마               장준환 김윤석
# 2  CJ ENM                  15세이상관람가 드라마               장준환 하정우
# ...

# %%
df$영화명 <- as.character(df$영화명)
df$영화명 <- as.factor(df$영화명)

# %%
a<-table(df$영화명)
a
# Out:
#                             1987                             감기
#                                6                                2
#            강철중: 공공의 적 1-1                    거북이 달린다
#                                2                                4
#                         검사외전                      검은 사제들
#                                6                                4
#                             곡성                             공작
#                                2                                2
#                             공조                             관상
#                                2                                2
#                         국가대표                    국가부도의 날
#                                2                                2
#                군도: 민란의 시대                           군함도
#                               10                                4
#                             귀향                           기생충
# ...

# %%
df2<-df

# %% [markdown]
# 2 -> *5
# 4 -> *2 + 2개가 1개
# 6 -> *1 + 4개가 1개
# 8 -> *1 + 2개가 1개

# %%
tbl <- table(df$영화명)
nums <- c(2,4,6,8)
movieName <- names(tbl[tbl == nums[1]])
movieName
# Out:
#  [1] "감기"                           "강철중: 공공의 적 1-1"
#  [3] "곡성"                           "공작"
#  [5] "공조"                           "관상"
#  [7] "국가대표"                       "국가부도의 날"
#  [9] "귀향"                           "기생충"
# [11] "댄싱퀸"                         "럭키"
# [13] "마녀"                           "미녀는 괴로워"
# [15] "밀정"                           "봉오동 전투"
# [17] "부러진 화살"                    "사도"
# [19] "설국열차"                       "스파이"
# [21] "쌍화점"                         "아가씨"
# [23] "아저씨"                         "암수살인"
# [25] "역린"                           "완득이"
# [27] "완벽한 타인"                    "우리 생애 최고의 순간"
# [29] "이끼"                           "인천상륙작전"
# [31] "조선명탐정 : 각시투구꽃의 비밀" "조선명탐정 : 사라진 놉의 딸"
# [33] "최종병기 활"                    "친절한 금자씨"
# [35] "퀵"                             "타워"
# [37] "터널"                           "히말라야"

# %%
length(movieName)
df<-df2
# Out:
# [1] 38

# %%
movieName <- names(tbl[tbl == nums[1]])
for(i in 1:length(movieName)){
    df <- rbind(df,df[df$영화명 == movieName[i],],df[df$영화명 == movieName[i],],df[df$영화명 == movieName[i],],df[df$영화명 == movieName[i],])
}
movieName <- names(tbl[tbl == nums[2]])
for(i in 1:length(movieName)){
    df <- rbind(df,df[df$영화명 == movieName[i],],df[df$영화명 == movieName[i],][1:2,])
}
movieName <- names(tbl[tbl == nums[3]])
for(i in 1:length(movieName)){
    df <- rbind(df,df[df$영화명 == movieName[i],][1:4,])
}
movieName <- names(tbl[tbl == nums[4]])
for(i in 1:length(movieName)){
    df <- rbind(df,df[df$영화명 == movieName[i],][1:2,])
}

# %%
nrow(df)
# Out:
# [1] 610

# %%
table(df$영화명)
# Out:
#                             1987                             감기
#                               10                               10
#            강철중: 공공의 적 1-1                    거북이 달린다
#                               10                               10
#                         검사외전                      검은 사제들
#                               10                               10
#                             곡성                             공작
#                               10                               10
#                             공조                             관상
#                               10                               10
#                         국가대표                    국가부도의 날
#                               10                               10
#                군도: 민란의 시대                           군함도
#                               10                               10
#                             귀향                           기생충
# ...

# %%
df<- arrange(df,desc(누적관객수))
head(df)
# Out:
#   영화명 누적매출액  누적관객수 스크린수 상영횟수 개봉일     배급사
# 1 기생충 85883963645 10085275   1948     192855   2019-05-30 CJ ENM
# 2 기생충 85883963645 10085275   1948     192855   2019-05-30 CJ ENM
# 3 기생충 85883963645 10085275   1948     192855   2019-05-30 CJ ENM
# 4 기생충 85883963645 10085275   1948     192855   2019-05-30 CJ ENM
# 5 기생충 85883963645 10085275   1948     192855   2019-05-30 CJ ENM
# 6 기생충 85883963645 10085275   1948     192855   2019-05-30 CJ ENM
#   등급           장르   감독   배우   제작사             cluster 감독_배우
# 1 15세이상관람가 드라마 봉준호 송강호 (주)바른손이앤에이 3       송강호
# 2 15세이상관람가 드라마 봉준호 이선균 (주)바른손이앤에이 3       송강호
# 3 15세이상관람가 드라마 봉준호 송강호 (주)바른손이앤에이 3       송강호
# 4 15세이상관람가 드라마 봉준호 이선균 (주)바른손이앤에이 3       송강호
# 5 15세이상관람가 드라마 봉준호 송강호 (주)바른손이앤에이 3       송강호
# 6 15세이상관람가 드라마 봉준호 이선균 (주)바른손이앤에이 3       송강호

# %%
write.csv(df, "./movies/movies*10.csv",row.names=F)

# %%
df <- df[,-c(2,)]
# Out:
# Error in c(2, ): 인자 2는 비어있습니다
# Traceback:
#
# 1. df[, -c(2, )]
# 2. `[.data.frame`(df, , -c(2, ))

# %%
df<- df[,-12]

# %%
head(df)
# Out:
#   영화명 누적매출액  누적관객수 스크린수 상영횟수 배급사 등급           감독
# 1 기생충 85883963645 10085275   1948     192855   CJ ENM 15세이상관람가 봉준호
# 2 기생충 85883963645 10085275   1948     192855   CJ ENM 15세이상관람가 봉준호
# 3 기생충 85883963645 10085275   1948     192855   CJ ENM 15세이상관람가 봉준호
# 4 기생충 85883963645 10085275   1948     192855   CJ ENM 15세이상관람가 봉준호
# 5 기생충 85883963645 10085275   1948     192855   CJ ENM 15세이상관람가 봉준호
# 6 기생충 85883963645 10085275   1948     192855   CJ ENM 15세이상관람가 봉준호
#   배우   cluster 감독_배우
# 1 송강호 3       송강호
# 2 이선균 3       송강호
# 3 송강호 3       송강호
# 4 이선균 3       송강호
# 5 송강호 3       송강호
# 6 이선균 3       송강호

# %%
df<- df[,-1]

# %%
df$cluster <- as.factor(df$cluster)

# %%
# Out:
# Error in colMeans(x, na.rm = TRUE): 'x'는 반드시 수치형이어야 합니다
# Traceback:
#
# 1. as.data.frame(scale(df[, 2:5]))
# 2. scale(df[, 2:5])
# 3. scale.default(df[, 2:5])
# 4. colMeans(x, na.rm = TRUE)
